# %%
from cleanlab.filter import find_label_issues
from cleanlab.filter_test import find_label_issues_test
import numpy as np
from time import time

# %%
def normalize(arr): 
    normalized = np.zeros(arr.shape, dtype=np.float16) 
    for i, a in enumerate(arr): 
        normalized[i] = a / np.sum(a) 
    return normalized

# %%
def run_test(test_name, pred_probs, labels, multi_label=False, filter_by='prune_by_noise_rate', n_jobs=4):
    print("-------------------------------------\n")
    print(f"running test: {test_name}\n")
    start = time()
    issues_new_single = find_label_issues_test(pred_probs=pred_probs, labels=labels, n_jobs=1, multi_label=multi_label, filter_by=filter_by)
    print(f"new single: took {time()-start} s\n")
    start = time()
    issues_new_multi = find_label_issues_test(pred_probs=pred_probs, labels=labels, n_jobs=n_jobs, multi_label=multi_label, filter_by=filter_by)
    print(f"new multi: took {time()-start} s")
    print(f"diff from new single {np.sum(issues_new_single ^ issues_new_multi)}\n")
    start = time()
    issues_old_single = find_label_issues(pred_probs=pred_probs, labels=labels, n_jobs=1, multi_label=multi_label, filter_by=filter_by)
    print(f"old single: took {time()-start} s")
    print(f"diff from new single {np.sum(issues_new_single ^ issues_old_single)}")
    print(f"diff from new multi {np.sum(issues_new_multi ^ issues_old_single)}\n")
    start = time()
    issues_old_multi = find_label_issues(pred_probs=pred_probs, labels=labels, n_jobs=n_jobs, multi_label=multi_label, filter_by=filter_by)
    print(f"old multi: took {time()-start} s")
    print(f"diff from new single {np.sum(issues_new_single ^ issues_old_multi)}")
    print(f"diff from new multi {np.sum(issues_new_multi ^ issues_old_multi)}")
    print(f"diff from old single {np.sum(issues_old_single ^ issues_old_multi)}\n")

# %%
n_m = [(100, 5), (200000, 100)]
multi_labels = [False, True]
filter_ops = ['prune_by_noise_rate', 'prune_by_class', 'both', 'confident_learning', 'predicted_neq_given']

# %%
for nm in n_m:
    n, m = nm
    test_name = f"n={n}, m={m}, "
    pred_probs = np.random.randint(low=1, high=100, size=[n, m], dtype=np.uint8) 
    pred_probs = normalize(pred_probs) 
    for multi_label in multi_labels:
        if multi_label:
            labels = []
            for i in range(n):
                num_labels = np.random.randint(m)
                if num_labels > 0:
                    labels.append(list(set(np.random.randint(m, size=num_labels))))
                else:
                    labels.append([])
        else:
            labels = np.repeat(np.arange(m), n // m) 
        for filter_op in filter_ops:
            run_test(test_name + filter_op + ", " + ("multi label" if multi_label else "no multi label"), pred_probs, labels, multi_label, filter_op, n_jobs=10)
# Out:
# -------------------------------------
#
# running test: n=100, m=5, prune_by_noise_rate, no multi label
#
# new single: took 0.0023322105407714844 s
#
# new multi: took 0.09888935089111328 s
# diff from new single 0
#
# old single: took 0.0020956993103027344 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 0.09414935111999512 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
#
# -------------------------------------
#
# running test: n=100, m=5, prune_by_class, no multi label
#
# new single: took 0.0016834735870361328 s
#
# new multi: took 0.08662176132202148 s
# diff from new single 0
#
# old single: took 0.0018486976623535156 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 0.08423304557800293 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
#
# -------------------------------------
#
# running test: n=100, m=5, both, no multi label
#
# new single: took 0.0021774768829345703 s
#
# new multi: took 0.17805957794189453 s
# diff from new single 0
#
# old single: took 0.0021715164184570312 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 0.16907715797424316 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
#
# -------------------------------------
#
# running test: n=100, m=5, confident_learning, no multi label
#
# new single: took 0.0017619132995605469 s
#
# new multi: took 0.0010154247283935547 s
# diff from new single 0
#
# old single: took 0.0009775161743164062 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 0.0009949207305908203 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
#
# -------------------------------------
#
# running test: n=100, m=5, predicted_neq_given, no multi label
#
# new single: took 0.0011849403381347656 s
#
# new multi: took 0.0009984970092773438 s
# diff from new single 0
#
# old single: took 0.0010340213775634766 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 0.0010612010955810547 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
#
# -------------------------------------
#
# running test: n=100, m=5, prune_by_noise_rate, multi label
#
# new single: took 0.005489826202392578 s
#
# new multi: took 0.41976428031921387 s
# diff from new single 0
#
# old single: took 0.006384849548339844 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 0.42915987968444824 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
#
# -------------------------------------
#
# running test: n=100, m=5, prune_by_class, multi label
#
# new single: took 0.005930662155151367 s
#
# new multi: took 0.4185001850128174 s
# diff from new single 0
#
# old single: took 0.006029605865478516 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 0.42363619804382324 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
#
# -------------------------------------
#
# running test: n=100, m=5, both, multi label
#
# new single: took 0.006399869918823242 s
#
# new multi: took 0.8691813945770264 s
# diff from new single 0
#
# old single: took 0.00612330436706543 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 0.8602604866027832 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
#
# -------------------------------------
#
# running test: n=100, m=5, confident_learning, multi label
#
# new single: took 0.005227088928222656 s
#
# new multi: took 0.004142284393310547 s
# diff from new single 0
#
# old single: took 0.004362344741821289 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 0.004176616668701172 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
#
# -------------------------------------
#
# running test: n=100, m=5, predicted_neq_given, multi label
#
# new single: took 0.004830837249755859 s
#
# new multi: took 0.004542827606201172 s
# diff from new single 0
#
# old single: took 0.004616260528564453 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 0.00462031364440918 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
#
# -------------------------------------
#
# running test: n=200000, m=100, prune_by_noise_rate, no multi label
#
# new single: took 1.819340467453003 s
#
# new multi: took 1.203618049621582 s
# diff from new single 0
#
# old single: took 61.21806335449219 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 8.03154468536377 s
# diff from new single 60
# diff from new multi 60
# diff from old single 60
#
# -------------------------------------
#
# running test: n=200000, m=100, prune_by_class, no multi label
#
# new single: took 1.0223889350891113 s
#
# new multi: took 1.1282246112823486 s
# diff from new single 0
#
# old single: took 1.2976436614990234 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 4.36821722984314 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
#
# -------------------------------------
#
# running test: n=200000, m=100, both, no multi label
#
# new single: took 1.905872106552124 s
#
# new multi: took 1.3227159976959229 s
# diff from new single 0
#
# old single: took 61.77164149284363 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 8.040755987167358 s
# diff from new single 60
# diff from new multi 60
# diff from old single 60
#
# -------------------------------------
#
# running test: n=200000, m=100, confident_learning, no multi label
#
# new single: took 0.9911632537841797 s
#
# new multi: took 0.9872462749481201 s
# diff from new single 0
#
# old single: took 0.9872429370880127 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 0.9859974384307861 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
#
# -------------------------------------
#
# running test: n=200000, m=100, predicted_neq_given, no multi label
#
# new single: took 1.4743421077728271 s
#
# new multi: took 1.478761911392212 s
# diff from new single 0
#
# old single: took 1.4755191802978516 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 1.4747979640960693 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
#
# -------------------------------------
#
# running test: n=200000, m=100, prune_by_noise_rate, multi label
#
# new single: took 22.375781059265137 s
#
# new multi: took 39.04587697982788 s
# diff from new single 0
#
# old single: took 22.060762882232666 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 53.30884385108948 s
# diff from new single 13
# diff from new multi 13
# diff from old single 13
#
# -------------------------------------
#
# running test: n=200000, m=100, prune_by_class, multi label
#
# new single: took 22.236101627349854 s
#
# new multi: took 41.10706281661987 s
# diff from new single 0
#
# old single: took 21.723732471466064 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 52.925699949264526 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
#
# -------------------------------------
#
# running test: n=200000, m=100, both, multi label
#
# new single: took 22.8832528591156 s
#
# new multi: took 58.728224754333496 s
# diff from new single 0
#
# old single: took 22.623912572860718 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 70.21835494041443 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
#
# -------------------------------------
#
# running test: n=200000, m=100, confident_learning, multi label
#
# new single: took 21.489593744277954 s
#
# new multi: took 22.332577228546143 s
# diff from new single 0
#
# old single: took 21.399293661117554 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 22.17986512184143 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
#
# -------------------------------------
#
# running test: n=200000, m=100, predicted_neq_given, multi label
#
# new single: took 25.68123149871826 s
#
# new multi: took 26.05834650993347 s
# diff from new single 0
#
# old single: took 25.51305055618286 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 26.160625219345093 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
