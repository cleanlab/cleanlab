# %%
from cleanlab.filter import find_label_issues
#from cleanlab.filter_test import find_label_issues_test
import numpy as np
from time import time

# %%
def normalize(arr): 
    normalized = np.zeros(arr.shape, dtype=np.float16) 
    for i, a in enumerate(arr): 
        normalized[i] = a / np.sum(a) 
    return normalized

# %%
def run_test(test_name, pred_probs, labels, multi_label=False, filter_by='prune_by_noise_rate', n_jobs=4):
    print("-------------------------------------\n")
    print(f"running test: {test_name}\n")
    start = time()
    issues_new_single = find_label_issues(pred_probs=pred_probs, labels=labels, n_jobs=1, multi_label=multi_label, filter_by=filter_by)
    print(f"new single: took {time()-start} s\n")
    start = time()
    issues_new_multi = find_label_issues(pred_probs=pred_probs, labels=labels, n_jobs=n_jobs, multi_label=multi_label, filter_by=filter_by)
    print(f"new multi: took {time()-start} s")
    print(f"diff from new single {np.sum(issues_new_single ^ issues_new_multi)}\n")
    #start = time()
    #issues_old_single = find_label_issues(pred_probs=pred_probs, labels=labels, n_jobs=1, multi_label=multi_label, filter_by=filter_by)
    #print(f"old single: took {time()-start} s")
    #print(f"diff from new single {np.sum(issues_new_single ^ issues_old_single)}")
    #print(f"diff from new multi {np.sum(issues_new_multi ^ issues_old_single)}\n")
    #start = time()
    #issues_old_multi = find_label_issues(pred_probs=pred_probs, labels=labels, n_jobs=n_jobs, multi_label=multi_label, filter_by=filter_by)
    #print(f"old multi: took {time()-start} s")
    #print(f"diff from new single {np.sum(issues_new_single ^ issues_old_multi)}")
    #print(f"diff from new multi {np.sum(issues_new_multi ^ issues_old_multi)}")
    #print(f"diff from old single {np.sum(issues_old_single ^ issues_old_multi)}\n")

# %%
n_m = [(100, 5), (200000, 100)]
multi_labels = [False, True]
filter_ops = ['prune_by_noise_rate', 'prune_by_class', 'both', 'confident_learning', 'predicted_neq_given']

# %%
for nm in n_m:
    n, m = nm
    test_name = f"n={n}, m={m}, "
    pred_probs = np.random.randint(low=1, high=100, size=[n, m], dtype=np.uint8) 
    pred_probs = normalize(pred_probs) 
    for multi_label in multi_labels:
        if multi_label:
            labels = []
            for i in range(n):
                num_labels = np.random.randint(m)
                if num_labels > 0:
                    labels.append(list(set(np.random.randint(m, size=num_labels))))
                else:
                    labels.append([])
        else:
            labels = np.repeat(np.arange(m), n // m) 
        for filter_op in filter_ops:
            run_test(test_name + filter_op + ", " + ("multi label" if multi_label else "no multi label"), pred_probs, labels, multi_label, filter_op, n_jobs=10)
# Out:
# -------------------------------------
#
# running test: n=100, m=5, prune_by_noise_rate, no multi label
#
# new single: took 2.1493027210235596 s
#
# new multi: took 0.1927788257598877 s
# diff from new single 0
#
# -------------------------------------
#
# running test: n=100, m=5, prune_by_class, no multi label
#
# new single: took 0.0019636154174804688 s
#
# new multi: took 0.10764098167419434 s
# diff from new single 0
#
# -------------------------------------
#
# running test: n=100, m=5, both, no multi label
#
# new single: took 0.0027358531951904297 s
#
# new multi: took 0.21303081512451172 s
# diff from new single 0
#
# -------------------------------------
#
# running test: n=100, m=5, confident_learning, no multi label
#
# new single: took 0.002103090286254883 s
#
# new multi: took 0.0012431144714355469 s
# diff from new single 0
#
# -------------------------------------
#
# running test: n=100, m=5, predicted_neq_given, no multi label
#
# new single: took 0.0012843608856201172 s
#
# new multi: took 0.0010936260223388672 s
# diff from new single 0
#
# -------------------------------------
#
# running test: n=100, m=5, prune_by_noise_rate, multi label
#
# new single: took 0.023125648498535156 s
#
# new multi: took 0.5734598636627197 s
# diff from new single 0
#
# -------------------------------------
#
# running test: n=100, m=5, prune_by_class, multi label
#
# new single: took 0.007420778274536133 s
#
# new multi: took 0.5672314167022705 s
# diff from new single 0
#
# -------------------------------------
#
# running test: n=100, m=5, both, multi label
#
# new single: took 0.007260560989379883 s
#
# new multi: took 1.1346192359924316 s
# diff from new single 0
#
# -------------------------------------
#
# running test: n=100, m=5, confident_learning, multi label
#
# new single: took 0.006956577301025391 s
#
# new multi: took 0.005579710006713867 s
# diff from new single 0
#
# -------------------------------------
#
# running test: n=100, m=5, predicted_neq_given, multi label
#
# new single: took 0.00578618049621582 s
#
# new multi: took 0.005707979202270508 s
# diff from new single 0
#
# -------------------------------------
#
# running test: n=200000, m=100, prune_by_noise_rate, no multi label
#
# new single: took 2.1704297065734863 s
#
# new multi: took 1.4299697875976562 s
# diff from new single 0
#
# -------------------------------------
#
# running test: n=200000, m=100, prune_by_class, no multi label
#
# new single: took 1.2380361557006836 s
#
# new multi: took 1.3498845100402832 s
# diff from new single 0
#
# -------------------------------------
#
# running test: n=200000, m=100, both, no multi label
#
# new single: took 2.2354955673217773 s
#
# new multi: took 1.6146235466003418 s
# diff from new single 0
#
# -------------------------------------
#
# running test: n=200000, m=100, confident_learning, no multi label
#
# new single: took 1.212317705154419 s
#
# new multi: took 1.1704046726226807 s
# diff from new single 0
#
# -------------------------------------
#
# running test: n=200000, m=100, predicted_neq_given, no multi label
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
#      16     labels = np.repeat(np.arange(m), n // m)
#      17 for filter_op in filter_ops:
# ---> 18     run_test(test_name + filter_op + ", " + ("multi label" if multi_label else "no multi label"), pred_probs, labels, multi_label, filter_op, n_jobs=10)
#
# Input In [3], in run_test(test_name, pred_probs, labels, multi_label, filter_by, n_jobs)
#       3 print(f"running test: {test_name}\n")
#       4 start = time()
# ----> 5 issues_new_single = find_label_issues(pred_probs=pred_probs, labels=labels, n_jobs=1, multi_label=multi_label, filter_by=filter_by)
#       6 print(f"new single: took {time()-start} s\n")
#       7 start = time()
#
# File ~/Cleanlab/cleanlab/cleanlab/filter.py:384, in find_label_issues(labels, pred_probs, return_indices_ranked_by, rank_by_kwargs, filter_by, multi_label, frac_noise, num_to_remove_per_class, min_examples_per_class, confident_joint, n_jobs, verbose)
#     381         label_issues_mask[idx] = True
#     383 if filter_by == "predicted_neq_given":
# --> 384     label_issues_mask = find_predicted_neq_given(labels, pred_probs, multi_label=multi_label)
#     386 # Remove label issues if given label == model prediction
#     387 # TODO: consider use of _multiclass_crossval_predict() here
#     388 pred = pred_probs.argmax(axis=1)
#
# File ~/Cleanlab/cleanlab/cleanlab/filter.py:707, in find_predicted_neq_given(labels, pred_probs, multi_label)
#     683 def find_predicted_neq_given(
#     684     labels: LabelLike, pred_probs: np.ndarray, *, multi_label: bool = False
#     685 ) -> np.ndarray:
#     686     """A simple baseline approach that considers ``argmax(pred_probs) != labels`` as the examples with label issues.
#     687
#     688     Parameters
#    (...)
#     704       labeled with high confidence.
#     705     """
# --> 707     assert_valid_inputs(X=None, y=labels, pred_probs=pred_probs, multi_label=multi_label)
#     708     if multi_label:
#     709         if not isinstance(labels, list):
#
# File ~/Cleanlab/cleanlab/cleanlab/internal/validation.py:98, in assert_valid_inputs(X, y, pred_probs, multi_label, allow_missing_classes, allow_one_class)
#      94     raise ValueError(
#      95         f"pred_probs must have at least {highest_class} columns, based on the largest class index which appears in labels."
#      96     )
#      97 # Check for valid probabilities.
# ---> 98 if (np.min(pred_probs) < 0) or (np.max(pred_probs) > 1):
#      99     raise ValueError("Values in pred_probs must be between 0 and 1.")
#     100 if X is not None:
#
# File <__array_function__ internals>:5, in amax(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:2733, in amax(a, axis, out, keepdims, initial, where)
#    2617 @array_function_dispatch(_amax_dispatcher)
#    2618 def amax(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2619          where=np._NoValue):
#    2620     """
#    2621     Return the maximum of an array or maximum along an axis.
#    2622
#    (...)
#    2731     5
#    2732     """
# -> 2733     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2734                           keepdims=keepdims, initial=initial, where=where)
#
# File ~/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:87, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84         else:
#      85             return reduction(axis=axis, out=out, **passkwargs)
# ---> 87 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:
