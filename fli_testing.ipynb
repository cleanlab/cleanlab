# %%
from cleanlab.filter import find_label_issues
from cleanlab.filter_test import find_label_issues_test
import numpy as np
from time import time

# %%
def normalize(arr): 
    normalized = np.zeros(arr.shape, dtype=np.float16) 
    for i, a in enumerate(arr): 
        normalized[i] = a / np.sum(a) 
    return normalized

# %%
def run_test(test_name, pred_probs, labels, multi_label=False, filter_by='prune_by_noise_rate'):
    print("-------------------------------------\n")
    print(f"running test: {test_name}\n")
    start = time()
    issues_new_single = find_label_issues_test(pred_probs=pred_probs, labels=labels, n_jobs=1, multi_label=multi_label, filter_by=filter_by)
    print(f"new single: took {time()-start} s\n")
    start = time()
    issues_new_multi = find_label_issues_test(pred_probs=pred_probs, labels=labels, n_jobs=4, multi_label=multi_label, filter_by=filter_by)
    print(f"new multi: took {time()-start} s")
    print(f"diff from new single {np.sum(issues_new_single ^ issues_new_multi)}\n")
    start = time()
    issues_old_single = find_label_issues(pred_probs=pred_probs, labels=labels, n_jobs=1, multi_label=multi_label, filter_by=filter_by)
    print(f"old single: took {time()-start} s")
    print(f"diff from new single {np.sum(issues_new_single ^ issues_old_single)}")
    print(f"diff from new multi {np.sum(issues_new_multi ^ issues_old_single)}\n")
    start = time()
    issues_old_multi = find_label_issues(pred_probs=pred_probs, labels=labels, n_jobs=4, multi_label=multi_label, filter_by=filter_by)
    print(f"old multi: took {time()-start} s")
    print(f"diff from new single {np.sum(issues_new_single ^ issues_old_multi)}")
    print(f"diff from new multi {np.sum(issues_new_multi ^ issues_old_multi)}")
    print(f"diff from old single {np.sum(issues_old_single ^ issues_old_multi)}\n")

# %%
n_m = [(100, 5), (200000, 100)]
multi_labels = [False, True]
filter_ops = ['prune_by_noise_rate', 'prune_by_class', 'both', 'confident_learning', 'predicted_neq_given']

# %%
for nm in n_m:
    n, m = nm
    test_name = f"n={n}, m={m}, "
    pred_probs = np.random.randint(low=1, high=100, size=[n, m], dtype=np.uint8) 
    pred_probs = normalize(pred_probs) 
    for multi_label in multi_labels:
        if multi_label:
            labels = []
            for i in range(n):
                num_labels = np.random.randint(m)
                if num_labels > 0:
                    labels.append(list(set(np.random.randint(m, size=num_labels))))
                else:
                    labels.append([])
        else:
            labels = np.repeat(np.arange(m), n // m) 
        for filter_op in filter_ops:
            run_test(test_name + filter_op + ", " + ("multi label" if multi_label else "no multi label"), pred_probs, labels, multi_label, filter_op)
# Out:
# -------------------------------------
#
# running test: n=100, m=5, prune_by_noise_rate, no multi label
#
# new single: took 0.005946159362792969 s
#
# new multi: took 3.815850019454956 s
# diff from new single 0
#
# old single: took 0.0068569183349609375 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 3.8566620349884033 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
#
# -------------------------------------
#
# running test: n=100, m=5, prune_by_class, no multi label
#
# new single: took 0.008824825286865234 s
#
# new multi: took 3.7378530502319336 s
# diff from new single 0
#
# old single: took 0.005232095718383789 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 4.3800530433654785 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
#
# -------------------------------------
#
# running test: n=100, m=5, both, no multi label
#
# new single: took 0.0054149627685546875 s
#
# new multi: took 7.985211133956909 s
# diff from new single 0
#
# old single: took 0.008671998977661133 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 8.689269065856934 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
#
# -------------------------------------
#
# running test: n=100, m=5, confident_learning, no multi label
#
# new single: took 0.007658958435058594 s
#
# new multi: took 0.0027899742126464844 s
# diff from new single 0
#
# old single: took 0.004912853240966797 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 0.0035369396209716797 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
#
# -------------------------------------
#
# running test: n=100, m=5, predicted_neq_given, no multi label
#
# new single: took 0.004392862319946289 s
#
# new multi: took 0.002456188201904297 s
# diff from new single 0
#
# old single: took 0.003801107406616211 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 0.004553079605102539 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
#
# -------------------------------------
#
# running test: n=100, m=5, prune_by_noise_rate, multi label
#
# new single: took 0.015697956085205078 s
#
# new multi: took 13.810322284698486 s
# diff from new single 0
#
# old single: took 0.014904022216796875 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 21.90520668029785 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
#
# -------------------------------------
#
# running test: n=100, m=5, prune_by_class, multi label
#
# new single: took 0.018805980682373047 s
#
# new multi: took 19.665594816207886 s
# diff from new single 0
#
# old single: took 0.03725790977478027 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 37.2633421421051 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
#
# -------------------------------------
#
# running test: n=100, m=5, both, multi label
#
# new single: took 0.02536606788635254 s
#
# new multi: took 31.43493103981018 s
# diff from new single 0
#
# old single: took 0.017916202545166016 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 43.91806507110596 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
#
# -------------------------------------
#
# running test: n=100, m=5, confident_learning, multi label
#
# new single: took 0.01632213592529297 s
#
# new multi: took 0.010393857955932617 s
# diff from new single 0
#
# old single: took 0.008965015411376953 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 0.010008811950683594 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
#
# -------------------------------------
#
# running test: n=100, m=5, predicted_neq_given, multi label
#
# new single: took 0.01234579086303711 s
#
# new multi: took 0.009231805801391602 s
# diff from new single 0
#
# old single: took 0.012432098388671875 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 0.011229991912841797 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
#
# -------------------------------------
#
# running test: n=200000, m=100, prune_by_noise_rate, no multi label
#
# new single: took 1.640542984008789 s
#
# new multi: took 6.037600994110107 s
# diff from new single 0
#
# old single: took 81.25016021728516 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 53.52822303771973 s
# diff from new single 89
# diff from new multi 89
# diff from old single 89
#
# -------------------------------------
#
# running test: n=200000, m=100, prune_by_class, no multi label
#
# new single: took 0.6916379928588867 s
#
# new multi: took 4.670939207077026 s
# diff from new single 0
#
# old single: took 1.0731627941131592 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 10.576112985610962 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
#
# -------------------------------------
#
# running test: n=200000, m=100, both, no multi label
#
# new single: took 1.598653793334961 s
#
# new multi: took 9.851524114608765 s
# diff from new single 0
#
# old single: took 68.85068011283875 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 59.413333892822266 s
# diff from new single 89
# diff from new multi 89
# diff from old single 89
#
# -------------------------------------
#
# running test: n=200000, m=100, confident_learning, no multi label
#
# new single: took 0.6625170707702637 s
#
# new multi: took 0.6751182079315186 s
# diff from new single 0
#
# old single: took 0.7005472183227539 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 0.6958582401275635 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
#
# -------------------------------------
#
# running test: n=200000, m=100, predicted_neq_given, no multi label
#
# new single: took 0.9650030136108398 s
#
# new multi: took 1.0006020069122314 s
# diff from new single 0
#
# old single: took 1.0239429473876953 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 1.0130047798156738 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
#
# -------------------------------------
#
# running test: n=200000, m=100, prune_by_noise_rate, multi label
#
# new single: took 54.495691776275635 s
#
# new multi: took 325.4205071926117 s
# diff from new single 0
#
# old single: took 50.38097310066223 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 552.8129427433014 s
# diff from new single 31
# diff from new multi 31
# diff from old single 31
#
# -------------------------------------
#
# running test: n=200000, m=100, prune_by_class, multi label
#
# new single: took 59.96765375137329 s
#
# new multi: took 296.5850398540497 s
# diff from new single 0
#
# old single: took 58.27000284194946 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 502.32463002204895 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
#
# -------------------------------------
#
# running test: n=200000, m=100, both, multi label
#
# new single: took 51.7931489944458 s
#
# new multi: took 477.6315829753876 s
# diff from new single 0
#
# old single: took 54.12137699127197 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 745.0339169502258 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
#
# -------------------------------------
#
# running test: n=200000, m=100, confident_learning, multi label
#
# new single: took 48.55997180938721 s
#
# new multi: took 48.23425483703613 s
# diff from new single 0
#
# old single: took 50.662359952926636 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 48.513577938079834 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
#
# -------------------------------------
#
# running test: n=200000, m=100, predicted_neq_given, multi label
#
# new single: took 63.52328824996948 s
#
# new multi: took 63.29170799255371 s
# diff from new single 0
#
# old single: took 62.92736887931824 s
# diff from new single 0
# diff from new multi 0
#
# old multi: took 67.0793719291687 s
# diff from new single 0
# diff from new multi 0
# diff from old single 0
